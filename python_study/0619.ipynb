# %%
from sklearn.datasets import load_breast_cancer
bc = load_breast_cancer()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.datasets import load_breast_cancer
#       2 bc = load_breast_cancer()
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input

bc_nn = Sequential()
bc_nn.add(Input(shape=(30, )))   # 여기서 지정할 건 속성. 속성의 shape. 이미지 데이터를 받아오는 경우 shape이 3차원 (세로, 가로, 픽셀). 지금 쓰는 데이터는 텍스트 데이터이므로 이렇게 지정.

bc_nn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# 은닉층 생성
from tensorflow.keras.layers import Input, Dense

# %% [markdown]
# # 데이터를 쪼개는 게 배치.
# 모델 입장에서 500, 30 이 있는데, 500이라는 숫자는 모델이 아니라 컴퓨터 환경에 따라 사용자가 지정하는 것. 그러니까 임의의 숫자가 들어갈 수 잇음
# 그니깐? 사용자가 실제로 중요하게 해야하는 건 컬럼
# 개수는 배치 사이즈에 따라 달라질 수 있음
